# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


df = pd.read_csv("penguins_size.csv")


df.columns = df.columns.str.strip()

df.dropna(inplace=True)

# %%
plt.figure(figsize=(8, 5))
sns.barplot(x='sex', y='body_mass_g', data=df, estimator='mean')
plt.title('Average Body Mass by Sex')
plt.xlabel('Sex')
plt.ylabel('Body Mass (g)')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.histplot(df['culmen_length_mm'], bins=20, kde=True)
plt.title('Distribution of Culmen Length')
plt.xlabel('Culmen Length (mm)')
plt.ylabel('Frequency')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(x='species', y='flipper_length_mm', data=df)
plt.title('Flipper Length by Species')
plt.xlabel('Species')
plt.ylabel('Flipper Length (mm)')
plt.tight_layout()
plt.show()
